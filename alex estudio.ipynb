# %%
#importamos las librerías
import h5py
import pylab as pl

# %%
#leemos los archivos archivo
f1 = h5py.File('electromiograma/brazo/alex/MOVER BRAZO ALEX.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_1"]
f2 = h5py.File('electrocardiograma/corazon/alex/CORAZON ALEX.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_2"]
f3= h5py.File('electrodermal/palma mano/alex/ELECTRODERMAL ALEX.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_3"]

# %%
#Gráfica 1
pl.plot(f1)
pl.xlim(600,800)
# Out:
# (600.0, 800.0)

# %%
#Gráfica 2
pl.plot(f2)
pl.xlim(600,1200)
# Out:
# (600.0, 1200.0)

# %%
#Gráfica 3
pl.plot(f3)
pl.xlim(0,1500)
# Out:
# (0.0, 1500.0)
