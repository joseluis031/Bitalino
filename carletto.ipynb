# %%
import pylab as pl
import h5py

# %%
f1 = h5py.File('electromiograma/brazo/CARLOS A1/OpenSignals (r)evolution Report_2024-03-04_17-19-53.pdf.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_1"]
f2 = h5py.File('electrocardiograma/corazon/CARLOS A2/OpenSignals (r)evolution Report_2024-03-04_17-17-24.pdf.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_2"]
f3 = h5py.File('electrodermal/palma mano/CARLOS A3/OpenSignals (r)evolution Report_2024-03-04_17-21-39.pdf.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_3"]

# %%
pl.plot(f1)
pl.xlim(400, 650)
# Out:
# (400.0, 650.0)

# %%
pl.plot(f2)
pl.xlim(200, 650)
# Out:
# (200.0, 650.0)

# %%
pl.plot(f3)
pl.xlim(0, 1755)
# Out:
# (0.0, 1750.0)
