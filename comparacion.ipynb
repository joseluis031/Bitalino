# %%
import h5py
import pylab as pl

# Leemos el primer archivo
f1 = h5py.File('electromiograma/brazo/flecha/MOVER BRAZO FLECHA.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_1"][:, 0]

# Leemos el segundo archivo
f2 = h5py.File('electromiograma/brazo/german/MOVER BRAZO GERMAN.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_1"][:, 0]

f3=h5py.File('electromiograma/brazo/CARLOS A1/OpenSignals (r)evolution Report_2024-03-04_17-19-53.pdf.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_1"]

f4=h5py.File('electromiograma/brazo/alex/MOVER BRAZO ALEX.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_1"]

# Graficamos ambas señales
pl.plot(f1, label='Señal Flecha')
pl.plot(f2, label='Señal German')
pl.plot(f3, label='Señal Carlos')
pl.plot(f4, label='Señal Alex')

# Configuramos los límites del eje x
pl.xlim(0,200)

# Configuramos los límites del eje y
pl.ylim(200, 800)
# Mostramos la leyenda
pl.legend()

# Mostramos la gráfica
pl.show()

# %%
# Leemos el primer archivo
f1 = h5py.File('electrocardiograma/corazon/flecha/CORAZÓN FLECHA.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_2"][:, 0]

# Leemos el segundo archivo
f2 = h5py.File('electrocardiograma/corazon/german/CORAZÓN GERMAN.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_2"][:, 0]

f3 = h5py.File('electrocardiograma/corazon/CARLOS A2/OpenSignals (r)evolution Report_2024-03-04_17-17-24.pdf.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_2"]

f4 = h5py.File('electrocardiograma/corazon/alex/CORAZON ALEX.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_2"]

# Graficamos ambas señales
pl.plot(f1, label='Señal Flecha')
pl.plot(f2, label='Señal German')
pl.plot(f3, label='Señal Carlos')
pl.plot(f4, label='Señal Alex')
# Configuramos los límites del eje x
pl.xlim(100, 600)

# Mostramos la leyenda
pl.legend()

# Mostramos la gráfica
pl.show()

# %%
# Leemos el primer archivo
f1 = h5py.File('electrodermal/palma mano/flecha/ELECTRODERMAL FLECHA.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_3"][:, 0]

# Leemos el segundo archivo
f2 = h5py.File('electrodermal/palma mano/german/ELECTRODERMAL GERMAN.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_3"][:, 0]

f3 = h5py.File('electrodermal/palma mano/CARLOS A3/OpenSignals (r)evolution Report_2024-03-04_17-21-39.pdf.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_3"]

f4= h5py.File('electrodermal/palma mano/alex/ELECTRODERMAL ALEX.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_3"]
# Graficamos las tres señales
pl.plot(f1, label='Señal Flecha')
pl.plot(f2, label='Señal German')
pl.plot(f3, label='Señal Carlos')
pl.plot(f4, label='Señal Alex')

# Configuramos los límites del eje x
pl.xlim()

# Mostramos la leyenda
pl.legend()

# Mostramos la gráfica
pl.xlim(0,3000)
# Out:
# (0.0, 3000.0)
