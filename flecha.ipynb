# %% [markdown]
# ANÁLISIS FLECHA

# %%
#sacamos los datos del electromiograma y los graficamos

import h5py
import pylab as pl

#leemos el archivo
f = h5py.File('electromiograma/brazo/flecha/MOVER BRAZO FLECHA.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_1"][:,0]

#graficamos
pl.plot(f)
pl.xlim(200,600)
# Out:
# (200.0, 600.0)

# %%
#sacamos los datos del electrocardiograma y los graficamos

#leemos el archivo
f = h5py.File('electrocardiograma/corazon/flecha/CORAZÓN FLECHA.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_2"][:,0]

#graficamos
pl.plot(f)
pl.xlim(100,600)
# Out:
# (100.0, 600.0)

# %%
#sacamos los datos del electrodermal y los graficamos

#leemos el archivo
f = h5py.File('electrodermal/palma mano/flecha/ELECTRODERMAL FLECHA.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_3"][:,0]

#graficamos
pl.plot(f)
pl.xlim(0,2000)
# Out:
# (0.0, 2000.0)
