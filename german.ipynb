# %%
import pylab as pl
import h5py

# %%
f1 = h5py.File('electromiograma/brazo/german/MOVER BRAZO GERMAN.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_1"]
f2 = h5py.File('electrocardiograma/corazon/german/CORAZÓN GERMAN.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_2"]
f3 = h5py.File('electrodermal/palma mano/german/ELECTRODERMAL GERMAN.h5')["84:BA:20:5E:FF:67"]["raw"]["channel_3"]

# %%
pl.plot(f1)
pl.xlim(400, 650)
# Out:
# (400.0, 650.0)

# %%
pl.plot(f2)
pl.xlim(200, 650)
# Out:
# (200.0, 650.0)

# %%
pl.plot(f3)
pl.xlim(0, 6300)
# Out:
# (0.0, 6200.0)
